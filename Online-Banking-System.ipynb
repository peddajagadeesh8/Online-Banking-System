# %% [markdown]
# <h1>Project Title: online_banking_system</h1>
#     <h2>Purpose</h2>
#     <p><i>The purpose of the online banking system is to provide customers with a convenient, secure way to manage their accounts, perform transactions, and access banking services online. This system enhances customer experience by offering 24/7 accessibility and streamlined financial management.
# .<i></p>

# %% [markdown]
# <h2>Step 1. Downloading necessary packages </h2>

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2>Step 2. Importing necessary packages </h2>

# %%
#Python code for connecting to MySQL database using mysql-connector-python
import mysql.connector
import pandas as pd #for Data manipulation

# %% [markdown]
# <h2>Step 3. Establishing Connection (Database connectivity from python to mysql database) </h2>

# %%
#Python code for connecting to MySQL database using mysql-connector-python
import mysql.connector
import pandas as pd
connection = mysql.connector.connect(
user='root',
password='jerry',
host='localhost',
database='online_banking_system'
)

# Create a cursor object to execute SQL queries
cursor = connection.cursor()
# Query data from the 'Customers' table
cursor.execute('SELECT * FROM Customers')

#After fetching data from the database we are storing it in Pandas DataFrame
customer_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Accounts' table
cursor.execute('SELECT * FROM Accounts')
accounts_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Transactions' table
cursor.execute('SELECT * FROM Transactions')
transactions_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Loans' table
cursor.execute('SELECT * FROM Loans')
loans_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Branches' table
cursor.execute('SELECT * FROM Branches')
branches_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Query data from the 'Card' table
cursor.execute('SELECT * FROM Card')
card_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in
cursor.description])

# Library used for ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Step 4. Data View </h2>

# %%
# Print the first 5 rows of the DataFrame
print(customer_df.head())

print(accounts_df.head())

print(transactions_df.head())

print(loans_df.head())

print(branches_df.head())

print(card_df.head())
# Out:
#    CustomerID FirstName LastName                     Email PhoneNumber  Age
# 0           1      Amit   Sharma  1amit.sharma@example.com  9876543210   48
# 1           2      Neha    Verma   2neha.verma@example.com  9876543211   44
# 2           3       Raj    Kumar    3raj.kumar@example.com  9876543212   59
# 3           4     Priya    Singh  4priya.singh@example.com  9876543213   47
# 4           5     Vijay    Patel  5vijay.patel@example.com  9876543214   43
#    AccountID  CustomerID AccountType  Balance  DateOpened    Status
# 0          1           1     Savings  1500.00  2020-01-01    Active
# 1          2           1    Checking   500.00  2020-02-01    Active
# 2          3           2     Savings  2500.00  2019-03-01    Active
# 3          4           3    Checking   300.00  2021-04-01  Inactive
# 4          5           4     Savings  4000.00  2018-05-01    Active
#    TransactionID  AccountID TransactionType   Amount     TransactionDate  \
# ...

# %%
# Prints the list of column names of the dataset
accounts_df.columns
print(accounts_df.columns)

# Prints the list of column names of the dataset
transactions_df.columns
print(transactions_df.columns)

# Prints the list of column names of the dataset
loans_df.columns
print(loans_df.columns)

# Prints the list of column names of the dataset
branches_df.columns
print(branches_df.columns)

# Prints the list of column names of the dataset
customer_df.columns
print(customer_df.columns)

# Prints the list of column names of the dataset
card_df.columns
print(card_df.columns)
# Out:
# Index(['AccountID', 'CustomerID', 'AccountType', 'Balance', 'DateOpened',
#        'Status'],
#       dtype='object')
# Index(['TransactionID', 'AccountID', 'TransactionType', 'Amount',
#        'TransactionDate', 'Description'],
#       dtype='object')
# Index(['LoanID', 'CustomerID', 'LoanType', 'LoanAmount', 'InterestRate',
#        'LoanStartDate'],
#       dtype='object')
# Index(['BranchID', 'BranchName', 'BranchAddress', 'BranchPhone',
#        'BranchManagerID', 'IFSCCode'],
#       dtype='object')
# Index(['CustomerID', 'FirstName', 'LastName', 'Email', 'PhoneNumber', 'Age'], dtype='object')
# Index(['CardID', 'CardNumber', 'CardHolderName', 'ExpiryDate', 'CVV',
#        'CardType', 'IssuingBank', 'CustomerID'],
#       dtype='object')

# %%
# Displays the summary of the dataset
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerID   100 non-null    int64
#  1   FirstName    100 non-null    object
#  2   LastName     100 non-null    object
#  3   Email        100 non-null    object
#  4   PhoneNumber  100 non-null    object
#  5   Age          100 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# Displays the summary of the dataset
accounts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   AccountID    100 non-null    int64
#  1   CustomerID   100 non-null    int64
#  2   AccountType  100 non-null    object
#  3   Balance      100 non-null    object
#  4   DateOpened   100 non-null    object
#  5   Status       100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# Displays the summary of the dataset
loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LoanID         100 non-null    int64
#  1   CustomerID     100 non-null    int64
#  2   LoanType       100 non-null    object
#  3   LoanAmount     100 non-null    object
#  4   InterestRate   100 non-null    object
#  5   LoanStartDate  100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# Displays the summary of the dataset
branches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BranchID         100 non-null    int64
#  1   BranchName       100 non-null    object
#  2   BranchAddress    100 non-null    object
#  3   BranchPhone      100 non-null    object
#  4   BranchManagerID  100 non-null    int64
#  5   IFSCCode         100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
# Displays the summary of the dataset
transactions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TransactionID    100 non-null    int64
#  1   AccountID        100 non-null    int64
#  2   TransactionType  100 non-null    object
#  3   Amount           100 non-null    object
#  4   TransactionDate  100 non-null    datetime64[ns]
#  5   Description      100 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 4.8+ KB

# %%
# Displays the dimensions of the dataset as a tuple
customer_df.shape
print(customer_df.shape)

# Displays the dimensions of the dataset as a tuple
accounts_df.shape
print(accounts_df.shape)

# Displays the dimensions of the dataset as a tuple
loans_df.shape
print(loans_df.shape)

# Displays the dimensions of the dataset as a tuple
transactions_df.shape
print(transactions_df.shape)

# Displays the dimensions of the dataset as a tuple
branches_df.shape
print(branches_df.shape)

# Displays the dimensions of the dataset as a tuple
card_df.shape
print(card_df.shape)
# Out:
# (100, 6)
# (100, 6)
# (100, 6)
# (100, 6)
# (100, 6)
# (100, 8)

# %%
# Displays the data types of each column
customer_df.dtypes
# Out:
# CustomerID      int64
# FirstName      object
# LastName       object
# Email          object
# PhoneNumber    object
# Age             int64
# dtype: object

# %%
# Displays the data types of each column
accounts_df.dtypes
# Out:
# AccountID       int64
# CustomerID      int64
# AccountType    object
# Balance        object
# DateOpened     object
# Status         object
# dtype: object

# %%
# Displays the data types of each column
transactions_df.dtypes
# Out:
# TransactionID               int64
# AccountID                   int64
# TransactionType            object
# Amount                     object
# TransactionDate    datetime64[ns]
# Description                object
# dtype: object

# %%
# Displays the data types of each column
loans_df.dtypes
# Out:
# LoanID            int64
# CustomerID        int64
# LoanType         object
# LoanAmount       object
# InterestRate     object
# LoanStartDate    object
# dtype: object

# %%
# Displays the data types of each column
branches_df.dtypes
# Out:
# BranchID            int64
# BranchName         object
# BranchAddress      object
# BranchPhone        object
# BranchManagerID     int64
# IFSCCode           object
# dtype: object

# %%
# Generate descriptive statistics of the numerical columns in the DataFrame
customer_df.describe()
# Out:
#        CustomerID         Age
# count  100.000000  100.000000
# mean    50.500000   42.910000
# std     29.011492   14.442568
# min      1.000000   18.000000
# 25%     25.750000   30.750000
# 50%     50.500000   43.500000
# 75%     75.250000   56.250000
# max    100.000000   65.000000

# %%
# Generating descriptive statistics of the numerical columns in a dataset
accounts_df.describe()
# Out:
#         AccountID  CustomerID
# count  100.000000  100.000000
# mean    50.500000   49.510000
# std     29.011492   28.994425
# min      1.000000    1.000000
# 25%     25.750000   24.750000
# 50%     50.500000   49.500000
# 75%     75.250000   74.250000
# max    100.000000   99.000000

# %%
# Generating descriptive statistics of the numerical columns in a dataset
transactions_df.describe()
# Out:
#        TransactionID   AccountID                TransactionDate
# count     100.000000  100.000000                            100
# mean       50.500000   49.510000  2023-02-20 06:37:12.000000256
# min         1.000000    1.000000            2023-01-01 10:00:00
# 25%        25.750000   24.750000            2023-01-26 06:45:00
# 50%        50.500000   49.500000            2023-02-20 03:30:00
# 75%        75.250000   74.250000            2023-03-17 22:30:00
# max       100.000000   99.000000            2023-04-10 10:00:00
# std        29.011492   28.994425                            NaN

# %%
# Generating descriptive statistics of the numerical columns in a dataset
loans_df.describe()
# Out:
#            LoanID  CustomerID
# count  100.000000  100.000000
# mean    50.500000   50.500000
# std     29.011492   29.011492
# min      1.000000    1.000000
# 25%     25.750000   25.750000
# 50%     50.500000   50.500000
# 75%     75.250000   75.250000
# max    100.000000  100.000000

# %%
# Generating descriptive statistics of the numerical columns in a dataset
branches_df.describe()
# Out:
#          BranchID  BranchManagerID
# count  100.000000       100.000000
# mean    50.500000        50.500000
# std     29.011492        29.011492
# min      1.000000         1.000000
# 25%     25.750000        25.750000
# 50%     50.500000        50.500000
# 75%     75.250000        75.250000
# max    100.000000       100.000000

# %%
# Generating descriptive statistics of the numerical columns in a dataset
card_df.describe()
# Out:
#            CardID         CVV  CustomerID
# count  100.000000  100.000000  100.000000
# mean    50.500000  493.950000   50.500000
# std     29.011492  304.886711   29.011492
# min      1.000000   12.000000    1.000000
# 25%     25.750000  234.000000   25.750000
# 50%     50.500000  456.000000   50.500000
# 75%     75.250000  789.000000   75.250000
# max    100.000000  901.000000  100.000000

# %% [markdown]
# <h2>Step 5. Data Cleaning </h2>

# %%
# Print the number of null values in each column of the customer_df DataFrame
print(customer_df.isnull().sum())

# Print the number of null values in each column of the accounts_df DataFrame
print(accounts_df.isnull().sum())

# Print the number of null values in each column of the transactions_df DataFrame
print(transactions_df.isnull().sum())

# Print the number of null values in each column of the loans_df DataFrame
print(loans_df.isnull().sum())

# Print the number of null values in each column of the branches_df DataFrame
print(branches_df.isnull().sum())

# Print the number of null values in each column of the card_df DataFrame
print(card_df.isnull().sum())
# Out:
# CustomerID     0
# FirstName      0
# LastName       0
# Email          0
# PhoneNumber    0
# Age            0
# dtype: int64
# AccountID      0
# CustomerID     0
# AccountType    0
# Balance        0
# DateOpened     0
# Status         0
# dtype: int64
# TransactionID      0
# AccountID          0
# TransactionType    0
# Amount             0
# TransactionDate    0
# Description        0
# dtype: int64
# LoanID           0
# CustomerID       0
# LoanType         0
# LoanAmount       0
# InterestRate     0
# LoanStartDate    0
# dtype: int64
# BranchID           0
# BranchName         0
# BranchAddress      0
# BranchPhone        0
# BranchManagerID    0
# IFSCCode           0
# dtype: int64
# CardID            0
# CardNumber        0
# CardHolderName    0
# ExpiryDate        0
# CVV               0
# CardType          0
# IssuingBank       0
# CustomerID        0
# dtype: int64

# %%
# Print the Balance column of the accounts_df DataFrame
print(accounts_df.Balance)

# Print the number of null values in the Balance column of the accounts_df DataFrame
print('Null values of Balance are: ', accounts_df.Balance.isnull().sum())
# Out:
# 0     1500.0
# 1      500.0
# 2     2500.0
# 3      300.0
# 4     4000.0
#        ...
# 95    6300.0
# 96    4900.0
# 97    6400.0
# 98    5000.0
# 99    6500.0
# Name: Balance, Length: 100, dtype: float64
# Null values of Balance are:  0

# %%
accounts_df.Balance.value_counts()
# Out:
# Balance
# 3600.0    3
# 3700.0    3
# 4500.0    3
# 4100.0    3
# 4200.0    3
#          ..
# 500.0     1
# 1900.0    1
# 2000.0    1
# 2100.0    1
# 6500.0    1
# Name: count, Length: 64, dtype: int64

# %%
accounts_df.Balance = pd.to_numeric(accounts_df.Balance)
accounts_df.Balance
# Out:
# 0     1500.0
# 1      500.0
# 2     2500.0
# 3      300.0
# 4     4000.0
#        ...
# 95    6300.0
# 96    4900.0
# 97    6400.0
# 98    5000.0
# 99    6500.0
# Name: Balance, Length: 100, dtype: float64

# %% [markdown]
# print(transactions_df.Amount)
# print ('Null values of Amount are: ', transactions_df.Amount.isnull().sum())

# %%
transactions_df.Amount.value_counts()
# Out:
# Amount
# 300.00     14
# 100.00     11
# 200.00     10
# 500.00     10
# 700.00      9
# 150.00      9
# 400.00      6
# 1000.00     5
# 800.00      5
# 600.00      5
# 250.00      5
# 900.00      5
# 350.00      5
# 50.00       1
# Name: count, dtype: int64

# %%
transactions_df.Amount = pd.to_numeric(transactions_df.Amount)
transactions_df.Amount
# Out:
# 0     1000.0
# 1      200.0
# 2      500.0
# 3      100.0
# 4      300.0
#        ...
# 95     250.0
# 96     900.0
# 97     350.0
# 98     500.0
# 99     100.0
# Name: Amount, Length: 100, dtype: float64

# %%
print(loans_df.LoanAmount)
print ('Null values of LoanAmount are: ', loans_df.LoanAmount.isnull().sum())
# Out:
# 0     250000.00
# 1      15000.00
# 2       5000.00
# 3      20000.00
# 4     300000.00
#         ...
# 95     44000.00
# 96    300000.00
# 97     31000.00
# 98     29000.00
# 99     45000.00
# Name: LoanAmount, Length: 100, dtype: object
# Null values of LoanAmount are:  0

# %%
loans_df.LoanAmount.value_counts()
# Out:
# LoanAmount
# 22000.00     4
# 25000.00     4
# 24000.00     4
# 27000.00     4
# 23000.00     4
# 330000.00    4
# 26000.00     4
# 20000.00     4
# 29000.00     3
# 28000.00     3
# 320000.00    3
# 300000.00    3
# 21000.00     3
# 310000.00    3
# 340000.00    2
# 17000.00     2
# 15000.00     2
# 30000.00     2
# 280000.00    2
# 31000.00     2
# 19000.00     2
# 18000.00     2
# 290000.00    2
# 16000.00     2
# 38000.00     1
# 35000.00     1
# 44000.00     1
# 34000.00     1
# 43000.00     1
# 42000.00     1
# 41000.00     1
# 390000.00    1
# 33000.00     1
# 36000.00     1
# 40000.00     1
# 37000.00     1
# 39000.00     1
# 380000.00    1
# 250000.00    1
# 32000.00     1
# 360000.00    1
# 14000.00     1
# 13000.00     1
# 295000.00    1
# 12000.00     1
# 11000.00     1
# 10000.00     1
# 9000.00      1
# 8000.00      1
# 6000.00      1
# 275000.00    1
# 7000.00      1
# 5000.00      1
# 45000.00     1
# Name: count, dtype: int64

# %%
loans_df.LoanAmount = pd.to_numeric(loans_df.LoanAmount)
loans_df.LoanAmount
# Out:
# 0     250000.0
# 1      15000.0
# 2       5000.0
# 3      20000.0
# 4     300000.0
#         ...
# 95     44000.0
# 96    300000.0
# 97     31000.0
# 98     29000.0
# 99     45000.0
# Name: LoanAmount, Length: 100, dtype: float64

# %%
print(loans_df.InterestRate)
print ('Null values of InterestRate are: ', loans_df.InterestRate.isnull().sum())
# Out:
# 0     3.50
# 1     5.00
# 2     7.50
# 3     4.00
# 4     3.60
#       ...
# 95    4.10
# 96    3.50
# 97    5.80
# 98    7.00
# 99    4.20
# Name: InterestRate, Length: 100, dtype: object
# Null values of InterestRate are:  0

# %%
loans_df.InterestRate.value_counts()
# Out:
# InterestRate
# 3.50    8
# 3.60    7
# 4.20    6
# 3.40    6
# 6.80    5
# 6.90    5
# 4.90    4
# 4.00    4
# 6.70    4
# 7.00    4
# 4.30    4
# 4.10    4
# 4.70    3
# 4.80    3
# 6.60    2
# 5.60    2
# 5.70    2
# 4.50    2
# 4.60    2
# 5.80    2
# 4.40    2
# 7.10    2
# 3.30    2
# 3.70    2
# 7.20    2
# 3.90    2
# 5.30    1
# 5.00    1
# 5.40    1
# 3.80    1
# 5.50    1
# 5.10    1
# 7.50    1
# 5.90    1
# 5.20    1
# Name: count, dtype: int64

# %%
# Convert the 'LoanAmount' column of the loans_df DataFrame to numeric data type
loans_df.LoanAmount = pd.to_numeric(loans_df.LoanAmount)

# Print the 'LoanAmount' column to verify the data type conversion
print(loans_df.LoanAmount)
# Out:
# 0     250000.0
# 1      15000.0
# 2       5000.0
# 3      20000.0
# 4     300000.0
#         ...
# 95     44000.0
# 96    300000.0
# 97     31000.0
# 98     29000.0
# 99     45000.0
# Name: LoanAmount, Length: 100, dtype: float64

# %%
# Get the unique values in the 'LoanType' column of the loans_df DataFrame
unique_loan_types = loans_df['LoanType'].unique()

# Print the unique loan types
print(unique_loan_types)
# Out:
# ['Home Loan' 'Car Loan' 'Personal Loan' 'Student Loan']

# %% [markdown]
# <h2>Step 6. Data Visualization </h2>

# %%
# Query data from the 'Loans' table to get the average loan amount per customer
cursor.execute('SELECT CustomerID, AVG(LoanAmount) AS AvgLoanAmount FROM Loans GROUP BY CustomerID;')

# Fetch the data and store it into a Pandas DataFrame
average_loan_amount_per_customer = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart of the average loan amount per customer
plt.figure(figsize=(12, 5))
plt.bar(average_loan_amount_per_customer['CustomerID'], average_loan_amount_per_customer['AvgLoanAmount'], color='skyblue')
plt.xlabel('Customer ID')
plt.ylabel('Average Loan Amount')
plt.title('Average Loan Amount per Customer')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Variation in Loan Amounts: There is a significant variation in the average loan amounts among different customers. Some customers have very high average loan amounts, while others have much lower amounts.
#
# High Loan Amounts: Certain customers have notably high average loan amounts, reaching up to around 350,000 to 400,000 units. These outliers could be due to specific high-value loans or a smaller number of loans with larger amounts.

# %%
# Query data from the 'Accounts' table and get the total balance by customer
cursor.execute('SELECT CustomerID, SUM(Balance) AS TotalBalance FROM Accounts GROUP BY CustomerID;')
import matplotlib.pyplot as plt
# Fetch the data and store it into a Pandas DataFrame
total_balance_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart of the total balance by customer
plt.figure(figsize=(12, 5))
plt.bar(total_balance_data['CustomerID'], total_balance_data['TotalBalance'], color='skyblue')
plt.xlabel('Customer ID')
plt.ylabel('Total Balance')
plt.title('Total Balance by Customer')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Increasing Trend: There is a noticeable increasing trend in the total balance as we move from left to right on the x-axis. This suggests that the customers are ordered by their total balance in ascending order.
#
# Variation in Balances: The total balances vary significantly among customers. While some customers have relatively low balances, others have much higher balances, reaching up to around 6000 units.

# %%
# Query data from the 'Customers' table and count the number of customers in each age group
cursor.execute('SELECT CASE \
                        WHEN Age >= 18 AND Age <= 25 THEN "18-25" \
                        WHEN Age >= 26 AND Age <= 35 THEN "26-35" \
                        WHEN Age >= 36 AND Age <= 45 THEN "36-45" \
                        WHEN Age >= 46 AND Age <= 55 THEN "46-55" \
                        ELSE "56+" \
                    END AS AgeGroup, \
                    COUNT(*) AS CustomerCount \
                FROM Customers \
                GROUP BY AgeGroup;')

# Fetch the data and store it into a Pandas DataFrame
customerCount_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a horizontal bar chart of the number of customers per age group
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 4))
plt.barh(customerCount_data['AgeGroup'], customerCount_data['CustomerCount'], color='skyblue')
plt.xlabel('Customer Count')
plt.ylabel('Age Group')
plt.title('Number of Customers per Age Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# Age Group Distribution:
#
# The age group 56+ has the highest number of customers, with around 25 customers.
# The age group 26-35 also has a significant number of customers, slightly less than the 56+ group.
# The age groups 46-55 and 36-45 have a moderate number of customers, with around 15 and 13 customers respectively.
# The age group 18-25 has the fewest customers, with around 10 customers.

# %%
import matplotlib.pyplot as plt

# Merge customer and account data frames on CustomerID
customer_accounts_df = pd.merge(customer_df, accounts_df, on='CustomerID')

# Plot a scatter plot of the age and balance of each customer
plt.scatter(customer_accounts_df['Age'], customer_accounts_df['Balance'])
plt.xlabel('Age')
plt.ylabel('Balance')
plt.title('Age vs. Account Balance')
plt.show()

# %% [markdown]
# Wide Range of Balances:
# A cluster of customers in their 20s and 30s with balances ranging from 1000 to 5000 units.
# A cluster of customers in their 50s and 60s with balances ranging from 2000 to 4000 units.

# %%
# Query data from the 'Accounts' table and count the number of accounts of each type
cursor.execute('SELECT AccountType, COUNT(*) AS AccountCount FROM Accounts GROUP BY AccountType;')

# Fetch the data and store it into a Pandas DataFrame
accountCount_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a pie chart of the distribution of account types
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 8))
plt.pie(accountCount_data['AccountCount'], labels=accountCount_data['AccountType'], autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Account Types')
plt.tight_layout()
plt.show()

# %% [markdown]
# Savings accounts usually earn more interest compared to checking accounts and are typically used for a financial goal or specific purpose
# Nearly Equal Distribution:
#
# The distribution between Savings and Checking accounts is almost equal, with Savings accounts making up 51.0% and Checking accounts making up 49.0% of the total accounts.
# Balanced Preferences:
#
# This near-equal split suggests that customers have a balanced preference for both types of accounts. It indicates that both Savings and Checking accounts are equally important to the customer base.

# %%
# Query data from the 'Card' table
cursor.execute('SELECT CardID, CardNumber, CardHolderName, ExpiryDate, CVV, CardType, IssuingBank, CustomerID FROM Card')

# Fetch the data and store it into a Pandas DataFrame
card_df = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart for the 'CardType' column
fig, axs = plt.subplots(2, 2, figsize=(20, 12))

card_df['CardType'].value_counts().plot(kind='bar', color='skyblue', ax=axs[0, 0])
axs[0, 0].set_xlabel('Card Type')
axs[0, 0].set_ylabel('Count')
axs[0, 0].set_title('Card Type Distribution')

# Query data from the 'Loans' table and count the number of loans by status
cursor.execute('SELECT Status, COUNT(*) AS LoanCount FROM accounts GROUP BY Status;')

# Fetch the data and store it into a Pandas DataFrame
loan_status_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart of the number of loans by status
loan_plot = axs[0, 1].bar(loan_status_data['Status'], loan_status_data['LoanCount'], color='skyblue')
axs[0, 1].set_xlabel('Loan Status')
axs[0, 1].set_ylabel('Loan Count')
axs[0, 1].set_title('Number of Loans by Loan Status')

# Query data from the 'Transactions' table and get the total transaction amount by account type
cursor.execute('SELECT AccountType, SUM(Balance) AS TotalAmount FROM accounts GROUP BY AccountType;')

# Fetch the data and store it into a Pandas DataFrame
total_transaction_accounttype_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart of the total transaction amount by account type
total_transaction_plot = axs[1, 0].bar(total_transaction_accounttype_data['AccountType'], total_transaction_accounttype_data['TotalAmount'], color='skyblue')
axs[1, 0].set_xlabel('Account Type')
axs[1, 0].set_ylabel('Total Transaction Amount')
axs[1, 0].set_title('Total Transaction Amount by Account Type')

# Query data from the 'Accounts' table and get the average balance by account status
cursor.execute('SELECT Status, AVG(Balance) AS AverageBalance FROM Accounts GROUP BY Status;')

# Fetch the data and store it into a Pandas DataFrame
avg_balance_accountstatus_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a bar chart of the average balance by account status
avg_balance_plot = axs[1, 1].bar(avg_balance_accountstatus_data['Status'], avg_balance_accountstatus_data['AverageBalance'], color='skyblue')
axs[1, 1].set_xlabel('Account Status')
axs[1, 1].set_ylabel('Average Balance')
axs[1, 1].set_title('Average Balance by Account Status')

plt.show()

# %% [markdown]
# Equal Distribution:
#
# The distribution of card types is nearly equal, with a slight preference for credit cards over debit cards.
# Both credit and debit cards have counts slightly above 50.
#
# Active Loans Dominate:
#
# The majority of loans are active, with a count of approximately 70.
# Inactive loans have a significantly lower count, around 30.
# Loan Activity:
#
# The higher number of active loans suggests that most customers are currently engaged in loan repayment or have ongoing loan agreements.
# The lower number of inactive loans could indicate successful loan repayment.
#
#     Higher Transactions in Savings Accounts:
#
# Savings accounts have a significantly higher total transaction amount compared to checking accounts.
# The total transaction amount for savings accounts is over 200,000 units, while for checking accounts, it is slightly above 100,000 units.
# Preference for Savings Accounts:
#
# The higher transaction amount in savings accounts suggests that customers might be using their savings accounts for larger or more frequent transactions compared to checking accounts.

# %%
# Query data from the 'Loans' table to get the loan amounts by loan type
cursor.execute('SELECT LoanType, LoanAmount FROM Loans;')

# Fetch the data and store it into a Pandas DataFrame
loan_amounts = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a boxplot of loan amounts by loan type
plt.figure(figsize=(10, 5))
sns.boxplot(data=loan_amounts, x='LoanType', y='LoanAmount')
plt.xlabel('Loan Type')
plt.ylabel('Loan Amount')
plt.title('Loan Amounts by Loan Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# Loan Amount Distribution:
#
# Home loans are significantly larger than other types of loans, reflecting the high cost of purchasing property.
# Car, personal, and student loans are smaller, with student loans being the largest among them.

# %%
# Query data from the 'Loans' table to get the distribution of loan types
cursor.execute('SELECT LoanType, COUNT(*) AS LoanCount FROM Loans GROUP BY LoanType;')

# Fetch the data and store it into a Pandas DataFrame
loan_types_distribution = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a pie chart of the loan types distribution
plt.figure(figsize=(5, 5))
plt.pie(loan_types_distribution['LoanCount'], labels=loan_types_distribution['LoanType'], autopct='%1.1f%%', startangle=140)
plt.title('Loan Types Distribution')
plt.tight_layout()
plt.show()

# %% [markdown]
# Equal Distribution:
# Each loan type (Home Loan, Car Loan, Personal Loan, and Student Loan) makes up exactly 25% of the total loan distribution.

# %%
import matplotlib.pyplot as plt

# Set the size of the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Plot a scatter plot of the loan amount and interest rate for each loan
ax.scatter(loans_df['LoanAmount'], loans_df['InterestRate'])
ax.set_xlabel('Loan Amount')
ax.set_ylabel('Interest Rate')
ax.set_title('Loan Amount vs. Interest Rate')

plt.show()

# %% [markdown]
# Loan Amount and Interest Rate Relationship:
#
# There appears to be an inverse relationship between loan amount and interest rate. Larger loans tend to have lower interest rates, while smaller loans have higher interest rates.
# This could be due to the lower risk perceived by the lender for larger loans, possibly because they are often secured by collateral (e.g., mortgages).

# %%
# Count the number of unique cards by issuing bank
card_counts = card_df['IssuingBank'].value_counts()
import seaborn as sns
# Plot a bar chart of the number of cards by unique issuing bank
plt.figure(figsize=(20, 7))
sns.barplot(x=card_counts.index, y=card_counts.values, palette='muted')
plt.title('Number of Cards by Issuing Bank')
plt.xlabel('Issuing Bank')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# State Bank of India Leads:
#
# The State Bank of India (SBI) has issued the highest number of cards, with a count slightly above 10.
# Similar Counts for Other Banks:
#
# HDFC Bank, ICICI Bank, Axis Bank, Punjab National Bank, Canara Bank, Union Bank of India, Kotak Mahindra Bank, and Yes Bank have issued a similar number of cards, each with a count slightly below 10.
# Bank of Baroda has issued the fewest cards among the listed banks, with a count slightly below 9.

# %%
# Assuming 'TransactionDate' is a datetime column
transactions_df['Day'] = transactions_df['TransactionDate'].dt.day_name()
transactions_df['Hour'] = transactions_df['TransactionDate'].dt.hour

# Pivot table for heatmap
heatmap_data = transactions_df.pivot_table(index='Day', columns='Hour', values='Amount', aggfunc='sum')

# Set the figure size for the heatmap
plt.figure(figsize=(12, 8))

# Create a heatmap using the heatmap_data DataFrame, with annotations and a color map
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt='.1f')

# Set the title, x-axis label, and y-axis label for the heatmap
plt.title('Heatmap of Transaction Amounts by Day and Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Day of Week')

# Display the heatmap
plt.show()

# %% [markdown]
# Peak Day:
#
# Wednesday stands out as the peak day for transaction amounts. This could be due to mid-week shopping trends or specific promotions that occur on this day.
# Low Activity Days:
#
# Monday and Friday have the lowest transaction amounts. This might indicate that customers are less active in making transactions at the beginning and end of the workweek.
# Weekend Activity:
#
# Transaction amounts on weekends (Saturday and Sunday) are relatively high, suggesting increased consumer activity during these days.

# %%
# Query data from the 'Transactions' table and count the number of transactions by transaction type and account type
cursor.execute('''
SELECT TransactionType, 
       AccountType, 
       COUNT(*) AS TransactionCount 
FROM Transactions 
JOIN Accounts ON Transactions.AccountID = Accounts.AccountID
GROUP BY TransactionType, AccountType;
''')

# Fetch the data and store it into a Pandas DataFrame
transactions_type_account_data = pd.DataFrame(cursor.fetchall(), columns=[desc[0] for desc in cursor.description])

# Plot a grouped bar chart of the number of transactions by transaction type and account type
plt.figure(figsize=(14, 7))
sns.barplot(x='TransactionType', y='TransactionCount', hue='AccountType', data=transactions_type_account_data)
plt.xlabel('Transaction Type')
plt.ylabel('Transaction Count')
plt.title('Number of Transactions by Transaction Type and Account Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Account Type Preferences:
#
# Customers seem to prefer using savings accounts for deposits and checking accounts for withdrawals. This could be due to the nature of these accounts, where savings accounts are generally used for storing money and earning interest, while checking accounts are used for daily transactions and withdrawals.

# %% [markdown]
# <h2>Conclusion</h2>
# The analysis of these graphs reveals distinct patterns in customer behavior and preferences regarding account types, transaction activities, and loan characteristics. These insights can help financial institutions tailor their product offerings, marketing strategies, and customer education programs to better meet the needs and preferences of their customers. Further analysis, such as examining transaction amounts and customer segmentation, can provide deeper insights and support more targeted strategies.
